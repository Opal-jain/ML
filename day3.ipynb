# %%
import cv2 
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread('p.png.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1=plt.imread('p.png.jpg')
plt.imshow(img1)

# %%
img2= ski.io.imshow('p.png.jpg')
ski.io.imshow(img2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 img2= ski.io.imshow('p.png.jpg')
# ----> 2 ski.io.imshow(img2)
#
# File c:\Users\opal8\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\io\_io.py:166, in imshow(arr, plugin, **plugin_args)
#     164 if isinstance(arr, str):
#     165     arr = call_plugin('imread', arr, plugin=plugin)
# --> 166 return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#
# File c:\Users\opal8\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\io\manage_plugins.py:205, in call_plugin(kind, *args, **kwargs)
#     202     except IndexError:
#     203         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 205 return func(*args, **kwargs)
#
# File c:\Users\opal8\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:149, in imshow(image, ax, show_cbar, **kwargs)
#     146 import matplotlib.pyplot as plt
#     147 from mpl_toolkits.axes_grid1 import make_axes_locatable
# --> 149 lo, hi, cmap = _get_display_range(image)
#     151 kwargs.setdefault('interpolation', 'nearest')
#     152 kwargs.setdefault('cmap', cmap)
#
# File c:\Users\opal8\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:95, in _get_display_range(image)
#      80 def _get_display_range(image):
#      81     """Return the display range for a given set of image properties.
#      82
#      83     Parameters
#    (...)
#      93         The name of the colormap to use.
#      94     """
# ---> 95     ip = _get_image_properties(image)
#      96     immin, immax = np.min(image), np.max(image)
#      97     if ip.signed:
#
# File c:\Users\opal8\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:43, in _get_image_properties(image)
#      20 """Determine nonstandard properties of an input image.
#      21
#      22 Parameters
#    (...)
#      40       standard skimage type, e.g. ``numpy.uint64``.
#      41 """
#      42 immin, immax = np.min(image), np.max(image)
# ---> 43 imtype = image.dtype.type
#      44 try:
#      45     lo, hi = dtypes.dtype_range[imtype]
#
# AttributeError: 'AxesImage' object has no attribute 'dtype'

# %%
ski.io.imsave('myfile.png',img)
plt.imsave('myfile2.png',img)
cv2.imwrite('myfile3.png',img)
# Out:
# True

# %%
img_gray=cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
ski.io.imshow(img_gray,)

# %%
img_gray
# Out:
# array([[71, 77, 77, ..., 41, 41, 41],
#        [71, 77, 77, ..., 45, 45, 45],
#        [71, 77, 77, ..., 45, 45, 45],
#        ...,
#        [28, 24, 24, ..., 41, 41, 41],
#        [26, 21, 21, ..., 42, 42, 42],
#        [25, 20, 20, ..., 42, 42, 42]], dtype=uint8)
